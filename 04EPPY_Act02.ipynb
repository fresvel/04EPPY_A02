# %% [markdown]
# <img src="../img/viu_logo.png" width="200">
#
# ## Estudiante:
# Velasteguí Izurieta Homero Javier
#
#
# ## 04EPPY - Actividad 2
#
# 25% de la Nota Final
#
# ### Fecha Entrega
# - Convocatoria 1 - 25/03/2024
# - Convocatoria 2 - 18/04/2024
#
# ### Instrucciones:
# - Crear un notebook de Python3 que servirá como entrega de la actividad.
# - Separar bien los apartados propuestos con celdas Markdown.
# - Mantener una estructura limpia, comentando código y secuenciando los apartados con el código correspondiente que resuelva la actividad.
# - Como criterio de evaluación se tendrá en cuenta el resultado, la consecución del mismo, estilo, comentarios y adecuación.
# - No está permitido compartir los resultados ni el código en ninguno de los foros.
#
# ### Entrega:
# - Un solo documento en formato notebook: .ipynb
# - Para hacer la entrega hay que subir el notebook al repositorio en la actividad de blackboard.

# %% [markdown]
# # **Olympics**

# %% [markdown]
# ## **A1 - Leer Datasets - 10%**
#
# - En Kaggle existen dos datasets sobre las olimpiadas modernas
#   - Atletas y resultados de medallas, desde 1896 a 2016, https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results
#   - Resultados de atletismo, desde 1896 a 2016, https://www.kaggle.com/jayrav13/olympic-track-field-results
#
# - Obtener y leer los ficheros csv en dataframes de pandas

# %%
#Resultados Generales de las Olimpiadas
import os

import kagglehub
import pandas as pd

# Se obtuvieron los datasets de kaggle mediante los siguientes comandos
data_olimpiadas = kagglehub.dataset_download("heesoo37/120-years-of-olympic-history-athletes-and-results")
data_atletismo = kagglehub.dataset_download("jayrav13/olympic-track-field-results")

#Una vez obtenidos los datasets se copiaron manualmente los mismos a las siguiente rutas:
path_olympics=os.path.join('.','datasets', 'olympics_all', 'athlete_events.csv')
path_regions=os.path.join('.', 'datasets', 'olympics_all', 'noc_regions.csv')
path_atletismo=os.path.join('.','datasets', 'olympics_track', 'results.csv')

#Obtención de los dataframes
try: 
    df_olympics= pd.read_csv(path_olympics, delimiter=',')
    df_regions=pd.read_csv(path_regions, delimiter=',')
    df_atletismo=pd.read_csv(path_atletismo, on_bad_lines='skip')
except Exception as e:
    print(f"Ocurrió un error en la carga de información {e}")
    
    
display("Los dataframes se han cargado de manera exitosa")
# Out:
# 'Los dataframes se han cargado de manera exitosa'

# %% [markdown]
# ### **Resultado de las Olimpiadas**

# %%
display(df_olympics.head(5))
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ### **Regiones**

# %%
display(df_regions.head(5))
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# ## **Resultados de Atletismo**

# %%
display(df_atletismo.head(5))
# Out:
#   Gender       Event Location  Year Medal                   Name Nationality  \
# 0      M  10000M Men      Rio  2016     G          Mohamed FARAH         USA
# 1      M  10000M Men      Rio  2016     S  Paul Kipngetich TANUI         KEN
# 2      M  10000M Men      Rio  2016     B           Tamirat TOLA         ETH
# 3      M  10000M Men  Beijing  2008     G        Kenenisa BEKELE         ETH
# 4      M  10000M Men  Beijing  2008     S         Sileshi SIHINE         ETH
#
#      Result
# 0  25:05.17
# 1  27:05.64
# 2  27:06.26
# 3  27:01.17
# 4  27:02.77

# %% [markdown]
# ### **A2 - Análisis - 45%**
# - Obtener un gráfico de barras con la evolución del número de deportes por año, eje X años, eje Y número de deportes
# ![sports_per_year](res/sports_per_year.png)
#
# ### **Solución:**

# %%
# Asegurarse de ejecutar las secciones anteriores
import seaborn as sns
import matplotlib.pyplot as plt


#Analizando los datos se ha identificado que la gráfica corresponde 
#a los datos de las olimpiadas de verano, por lo que se ejecuta un filtro

df_olympics = df_olympics[df_olympics['Games'].str.contains('Summer', case=False, na=False)]

deportes_x_anio= df_olympics.groupby('Year')['Sport'].nunique().reset_index()



#display(df_verano)

plt.figure(figsize=(10, 6))
custom_palette=sns.color_palette("pastel", len(deportes_x_anio))
display(custom_palette)

sns.barplot(x=deportes_x_anio['Year'], hue=deportes_x_anio['Year'], legend=False, y=deportes_x_anio['Sport'], palette=custom_palette)
# Personalizar el gráfico
plt.title('Número de Deportes por Año', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Número de Deportes', fontsize=12)
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098)]

# %% [markdown]
# - Gráfico con la evolución de la participación femenina en las olimpiadas a lo largo de la historia, eje X años, eje Y número de atletas, para cada año una barra para cada sexo
# ![sex](res/sex.png)
#
# ### **Solución**

# %%
#Para mostrar la solución de este ejercicio, ejecutar todas las secciones 
#anteriones

#Analizando los datos se ha identificado que la gráfica corresponde 
#a los datos de las olimpiadas de verano, por lo que se ejecuta un filtro

df_olympics = df_olympics[df_olympics['Games'].str.contains('Summer', case=False, na=False)]
#Se elimina los registros duplicados de los atletas que en un mismo año participaron en varias 
#disciplinas.
df_olympics=df_olympics.drop_duplicates(subset=['Year', 'Name'])

df_sex_analisis=df_olympics.groupby(by=['Year', 'Sex']).count().reset_index()[['Year','Sex', 'ID']]

plt.figure(figsize=(10, 6))
sns.barplot(x=df_sex_analisis['Year'], y=df_sex_analisis['ID'], hue=df_sex_analisis['Sex'], palette=custom_palette[12:14])
plt.title("Análisis por Sexo", fontsize=12)
plt.ylabel("Número de Atletas", fontsize=12)
plt.xlabel("Año", fontsize=12)
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()

plt.show()

# %% [markdown]
# - Gráfico con los 50 paises con más medallas en toda la historia, en cada barra el nombre completo del pais, longitud de cada barra, total de medallas obtenidas por pais
# ![medallero](res/medallero.png)
#
# ### **Solución**

# %%
## Para obtener la solución se debe ejecutar el primer script de este documento


df_olympics= pd.read_csv(path_olympics, delimiter=',')


df_olympics = df_olympics[df_olympics['Games'].str.contains('Summer', case=False, na=False)]


df_medal_country=df_olympics[df_olympics['Medal'].notna()]


df_num_medals= df_medal_country['Team'].value_counts()

df_top_countries=df_num_medals.sort_values(ascending=False).iloc[:50]


custom_palette=sns.color_palette("pastel", len(df_top_countries))
display(custom_palette)

plt.figure(figsize=(10,10))
ax=sns.barplot(x=df_top_countries.values, y=df_top_countries.index,  hue=df_top_countries.index, palette=custom_palette)

ax.xaxis.grid(True)
# Poner el número de medallas al final de cada barra
for i, (value, name) in enumerate(zip(df_top_countries.values, df_top_countries.index)):
    ax.text(value + 1, i, str(value), va='center', fontsize=8)  # value+1 para que el texto no quede dentro de la barra



plt.title("Top Fifty Countries with More Medals")
plt.ylabel("Countries", fontsize=12)
plt.xlabel("Number of Medals", fontsize=12)
plt.yticks(fontsize=8)


plt.tight_layout()
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %% [markdown]
# ### A3 - Machine Learning - 45%
#
# - Crear un modelo capaz de predecir el tiempo que va a hacer un atleta en la prueba de los 100 metros lisos, en función de su edad, sexo, peso y altura.
# ![model](res/model.png)

# %% [markdown]
# ### 1.- Importar las librerías necesarias

# %%
# Librerías necesarias
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import warnings

# Ignorar advertencias de líneas corruptas
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2.- Cargar y procesar los datasets

# %%
path_olympics=os.path.join('.','datasets', 'olympics_all', 'athlete_events.csv')
path_regions=os.path.join('.', 'datasets', 'olympics_all', 'noc_regions.csv')
path_atletismo=os.path.join('.','datasets', 'olympics_track', 'results.csv')

#Obtención de los dataframes
try: 
    df_olympics= pd.read_csv(path_olympics, delimiter=',')
    df_regions=pd.read_csv(path_regions, delimiter=',')
    df_atletismo=pd.read_csv(path_atletismo, on_bad_lines='skip')
except Exception as e:
    print(f"Ocurrió un error en la carga de información {e}")


##Tratamiento de datos de df_atletismo
## Filtro de información a el evento de 100 metros lisos
mask=df_atletismo["Event"].str.fullmatch(r'(100M Men|100M Women)', case=False)
df_atletismo=df_atletismo[mask]

print(f"Número de registros de df_atletismo: {mask.sum()}")

##Tratamiento de datos de df_olympics
#df_olympics = df_olympics[df_olympics['Games'].str.contains('Summer', case=False, na=False)]
mask=df_olympics["Event"].str.fullmatch(r"(Athletics Women's 100 metres|Athletics Men's 100 metres)", case=False)
df_olympics=df_olympics[mask]
print(f"Número de registros de df_olympics: {mask.sum()}")



## Analisis de valores de Medal
medal_atletismo=df_atletismo['Medal'].unique()
print(f"Valores de Medallas en df_atletismo {medal_atletismo}")

medal_olympics=df_olympics['Medal'].unique()
print(f"Valores de Medallas en df_olympics {medal_olympics}")
# Out:
# Número de registros de df_atletismo: 142
# Número de registros de df_olympics: 2999
# Valores de Medallas en df_atletismo ['G' 'S' 'B']
# Valores de Medallas en df_olympics [nan 'Gold' 'Silver' 'Bronze']

# %% [markdown]
# ### Análisis y Preparación de Datasets
# Se ha indentificado que el dataset de atletismo incluye los registros de tiempos solo para quienes obtuvieron medallas y no existen valores nulos. Con este análisis se determina que del df_olympics se puede obtener los valores de edad, peso y altura que se requieren para el modelo.

# %%
## Eliminación de nulos en df_olympics (Quienes no obtuvieron medalla)



print(len(df_olympics))
medal_mask = df_olympics['Medal'].notna()


df_olympics = df_olympics[medal_mask]
df_olympics.loc[df_olympics['Medal'] == 'Gold', 'Medal'] = 'G'
df_olympics.loc[df_olympics['Medal'] == 'Silver', 'Medal'] = 'S'
df_olympics.loc[df_olympics['Medal'] == 'Bronze', 'Medal'] = 'B'
print(f"Valores úninos de Medal en df_olympics {df_olympics['Medal'].unique()}")
display(df_olympics.sample(5))
print(df_olympics['Sex'].unique())


df_atletismo.loc[df_atletismo['Gender'] == 'M', 'Sex'] = 'M'
df_atletismo.loc[df_atletismo['Gender'] == 'W', 'Sex'] = 'F'

display(df_atletismo.sample(5))
# Out:
# 2999
# Valores úninos de Medal en df_olympics ['G' 'S' 'B']
#             ID                                    Name Sex   Age  Height  \
# 255711  128025  Stanisawa Walasiewicz (-Walsh, -Olson)   F  21.0   174.0
# 229348  115156                          Kerron Stewart   F  24.0   175.0
# 136814   68787                    Silvio Leonard Sarra   M  24.0   173.0
# 24883    13029                      Usain St. Leo Bolt   M  29.0   196.0
# 239294  119949                        Richard Thompson   M  23.0   188.0
#
#         Weight                 Team  NOC        Games  Year  Season  \
# 255711    60.0               Poland  POL  1932 Summer  1932  Summer
# 229348    61.0              Jamaica  JAM  2008 Summer  2008  Summer
# 136814    64.0                 Cuba  CUB  1980 Summer  1980  Summer
# 24883     95.0              Jamaica  JAM  2016 Summer  2016  Summer
# 239294    80.0  Trinidad and Tobago  TTO  2008 Summer  2008  Summer
#
#                   City      Sport                         Event Medal
# 255711     Los Angeles  Athletics  Athletics Women's 100 metres     G
# 229348         Beijing  Athletics  Athletics Women's 100 metres     S
# 136814          Moskva  Athletics    Athletics Men's 100 metres     S
# 24883   Rio de Janeiro  Athletics    Athletics Men's 100 metres     G
# 239294         Beijing  Athletics    Athletics Men's 100 metres     S
# ['M' 'F']
#      Gender       Event               Location  Year Medal  \
# 1708      W  100M Women              Amsterdam  1928     G
# 126       M    100M Men                  Tokyo  1964     G
# 96        M    100M Men                 Berlin  1936     G
# 129       M    100M Men  Melbourne / Stockholm  1956     G
# 1712      W  100M Women                 London  2012     S
#
#                     Name Nationality Result Sex
# 1708  Elizabeth ROBINSON         USA   12.2   F
# 126            Bob HAYES         USA   10.0   M
# 96           Jesse OWENS         USA   10.3   M
# 129         Bobby MORROW         USA   10.5   M
# 1712     Carmelita JETER         USA  10.78   F

# %% [markdown]
# ## Unión de Datasets

# %%
df_merged=df_atletismo.merge(df_olympics, on=["Year", "Medal", "Sex"], how="left")
df_model=df_merged[['Age','Sex', 'Weight', 'Height', 'Name_x', 'Name_y', 'Year', 'Result']]
display(df_model.sample(10))
# Out:
#       Age Sex  Weight  Height                 Name_x  \
# 79   24.0   M    56.0   167.0          Fritz HOFMANN
# 108  22.0   F    60.0   176.0     Irena KIRSZENSTEIN
# 10   24.0   M    73.0   180.0       Frank FREDERICKS
# 19   22.0   M    79.0   183.0          Lennox MILLER
# 2    21.0   M    70.0   176.0        Andre DE GRASSE
# 138  18.0   F    60.0   170.0        Ewa KLOBUKOWSKA
# 139  18.0   F    57.0   169.0         Betty CUTHBERT
# 124  25.0   F    62.0   176.0    Yuliya NESTSIARENKA
# 6    26.0   M    80.0   176.0         Maurice GREENE
# 131  22.0   F    55.0   165.0  Marlies OELSNER-GÃHR
#
#                                          Name_y  Year Result
# 79                                Fritz Hofmann  1896   12.2
# 108                 Irena Szewiska-Kirszenstein  1968   11.1
# 10                   Frank "Frankie" Fredericks  1992  10.02
# 19                       Lennox Valencia Miller  1968   10.0
# 2                               Andre De Grasse  2016   9.91
# 138                              Ewa Kobukowska  1964   11.6
# 139            Elizabeth Alyse "Betty" Cuthbert  1956   11.5
# 124  Yuliya Viktorovna Nesterenko (Bartsevich-)  2004  10.93
# 6                                Maurice Greene  2000   9.87
# 131                         Marlies Oelsner-Ghr  1980  11.07

# %% [markdown]
# ## Modelo de Entrenamiento

# %%
display(df_model.isnull().sum())
print(len(df_model))
df_model.dropna(inplace=True)
print(len(df_model))

le = LabelEncoder()
df_model['Sex'] = le.fit_transform(df_model['Sex'])


x = df_model[['Age', 'Sex', 'Weight', 'Height']]
y = df_model['Result']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Separar características (X) y la variable objetivo (y)
x = df_model[['Age', 'Sex', 'Weight', 'Height']]
y = df_model['Result']

# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Crear y entrenar el modelo
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Verificar el rendimiento del modelo (opcional)
print(f'R^2 score: {model.score(X_test, y_test)}')
# Out:
# Age       0
# Sex       0
# Weight    0
# Height    0
# Name_x    0
# Name_y    0
# Year      0
# Result    0
# dtype: int64
# 140
# 140
# R^2 score: 0.576827063020443

# %% [markdown]
# ### Función de Prueba

# %%
# Función para predecir el resultado de un nuevo atleta
def predecir_resultado():
    # Solicitar al usuario que ingrese los valores
    edad = float(input("Ingrese la Edad del atleta: "))
    sexo = input("Ingrese el Sexo del atleta (M o F): ")
    
    # Verificar que el sexo ingresado sea válido
    if sexo not in ['M', 'F']:
        print("Sexo inválido. Por favor ingrese 'M' o 'F'.")
        return
    
    peso = float(input("Ingrese el Peso del atleta (en kg): "))
    altura = float(input("Ingrese la Altura del atleta (en cm): "))

    # Transformar el sexo a numérico usando el mismo LabelEncoder
    # Primero, ajustamos el LabelEncoder con los datos de entrenamiento
    sexo_transformado = le.transform([sexo])[0]  # Convierte 'M' o 'F' a 0 o 1
    
    # Crear un DataFrame con los valores ingresados
    datos_ingresados = pd.DataFrame([[edad, sexo_transformado, peso, altura]], columns=['Age', 'Sex', 'Weight', 'Height'])
    
    # Realizar la predicción
    resultado_predicho = model.predict(datos_ingresados)
    
    print(f"El resultado predicho para el atleta es: {resultado_predicho[0]}")
    
# Llamar a la función para hacer una predicción
predecir_resultado()
